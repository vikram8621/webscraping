# %%
pip install selenium
# Out:
# ...
#                                               0.0/9.9 MB ? eta -:--:--
#                                               0.0/9.9 MB 1.4 MB/s eta 0:00:08
#                                               0.1/9.9 MB 1.1 MB/s eta 0:00:10
#                                               0.1/9.9 MB 1.1 MB/s eta 0:00:10
#                                               0.1/9.9 MB 901.1 kB/s eta 0:00:11
#                                               0.2/9.9 MB 952.6 kB/s eta 0:00:11
#                                               0.2/9.9 MB 908.0 kB/s eta 0:00:11
#                                               0.2/9.9 MB 942.1 kB/s eta 0:00:11
#      -                                        0.3/9.9 MB 911.0 kB/s eta 0:00:11
#      -                                        0.3/9.9 MB 842.9 kB/s eta 0:00:12
#      -                                        0.3/9.9 MB 855.7 kB/s eta 0:00:12
#      -                                        0.3/9.9 MB 855.7 kB/s eta 0:00:12
# ...

# %%
pip install nbconvert[webpdf]
# Out:
# ...
#                                               0.0/83.4 kB ? eta -:--:--
#      ---------------------------------------- 83.4/83.4 kB 4.6 MB/s eta 0:00:00
# ...
#                                               0.0/101.4 kB ? eta -:--:--
#      -------------------------------------- 101.4/101.4 kB 5.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px

# For HTML export

import plotly.io as pio
pio.renderers.default = 'notebook'

#  For PDF export
# !pip install Pyppeteer
# !pyppeteer-install
# Out:
# ...
# [INFO] Starting Chromium download.
#
#   0%|          | 0.00/137M [00:00<?, ?b/s]
#   0%|          | 51.2k/137M [00:00<12:39, 180kb/s]
#   0%|          | 81.9k/137M [00:00<15:27, 147kb/s]
#   0%|          | 133k/137M [00:00<10:09, 224kb/s]
#   0%|          | 184k/137M [00:00<07:59, 285kb/s]
#   0%|          | 236k/137M [00:00<06:45, 337kb/s]
#   0%|          | 307k/137M [00:00<05:13, 436kb/s]
#   0%|          | 430k/137M [00:01<03:34, 636kb/s]
#   0%|          | 573k/137M [00:01<02:43, 835kb/s]
#   1%|          | 778k/137M [00:01<01:56, 1.17Mb/s]
#   1%|          | 1.06M/137M [00:01<01:22, 1.64Mb/s]
#   1%|1         | 1.46M/137M [00:01<00:58, 2.30Mb/s]
#   1%|1         | 1.97M/137M [00:01<00:43, 3.09Mb/s]
#   2%|1         | 2.72M/137M [00:01<00:30, 4.39Mb/s]
#   3%|2         | 3.71M/137M [00:01<00:22, 5.98Mb/s]
#   4%|3         | 4.90M/137M [00:01<00:17, 7.71Mb/s]
#   4%|4         | 6.03M/137M [00:02<00:16, 7.86Mb/s]
#   5%|5         | 7.26M/137M [00:02<00:14, 9.06Mb/s]
# ...

# %% [markdown]
# The libraries used for this project

# %%
# Import Libraries

from bs4 import BeautifulSoup
import requests
import smtplib
import time
import datetime
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
import csv
import datetime
import pandas as pd

# %%
# Make timestamp for data collection

today = datetime.date.today()



# Set up the Selenium WebDriver with Chrome
chrome_path = 'C:\\Users\Vikram Aiyer\\Downloads\\chromedriver-win64\\chromedriver-win64\\chromedriver.exe'
service = ChromeService(chrome_path)
driver = webdriver.Chrome(service=service)
driver.get(URL)

# Wait for the page to load (you might need to adjust the sleep duration)
time.sleep(10)

# Get the page source after it has loaded dynamically
page_source = driver.page_source

# Use BeautifulSoup to parse the page source
soup = BeautifulSoup(page_source, 'html.parser')

# Find all products on the page
product_elements = soup.find_all('span', {'class': 'a-size-medium a-color-base a-text-normal'})

# write a header to CSV file
header = ['Title', 'Price', 'Date']
with open('AmazonWebScrapperDataset1.csv', 'a+', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    # If the file is empty, write the header
    if f.tell() == 0:
        writer.writerow(header)

    # Iterate over product elements
    for product_element in product_elements:
        # Extract and print the title for each product
        title = product_element.get_text(strip=True)
        print(f"Title: {title}")

        # Find the parent element containing the price
        parent_element = product_element.find_parent('div', {'class': 'a-section a-spacing-small a-spacing-top-small'})

        # Extract and print the price for each product
        price_element = product_element.find_next('span', {'class': 'a-price-whole'})

        # Check if the element with id 'a-price-whole' exists
        if price_element:
            price = price_element.get_text(strip=True)
            print(f"Price: {price}")
        else:
            print("Price not found.")

        # Write the data to CSV file
        data = [title, price, today]
        writer.writerow(data)

        print('-' * 50)

# Read and display the CSV file
df = pd.read_csv('AmazonWebScrapperDataset1.csv')
print(df)

# Close the Selenium WebDriver
driver.quit()
# Out:
# Title: Ninja Call Pro Plus 1.83" Smart Watch with Bluetooth Calling, AI Voice Assistance, 100 Sports Modes IP67 Rating, 240 * 280 Pixel High Resolution
# Price: 1,099
# --------------------------------------------------
# Title: Ninja Call Pro Plus 1.83" Smart Watch with Bluetooth Calling, AI Voice Assistance, 100 Sports Modes IP67 Rating, 240 * 280 Pixel High Resolution
# Price: 1,099
# --------------------------------------------------
# Title: Ninja Call Pro Plus 1.83" Smart Watch with Bluetooth Calling, AI Voice Assistance, 100 Sports Modes IP67 Rating, 240 * 280 Pixel High Resolution
# Price: 1,099
# --------------------------------------------------
# Title: Lunar Comet with 1.39" HD Display, Advanced Bluetooth Calling, Functional Crown, Multiple Sports Mode,100 Watch Faces, HR & SpO2 Monitoring,IP67, Smart Watch for Men & Women(Metal Grey)
# Price: 1,399
# --------------------------------------------------
# ...

# %%
# We are defining a function to check_price for the extracted data 
def check_price():
    # Set up the Selenium WebDriver with Chrome
    chrome_path = 'C:\\Users\Vikram Aiyer\\Downloads\\chromedriver-win64\\chromedriver-win64\\chromedriver.exe'
    service = ChromeService(chrome_path)
    driver = webdriver.Chrome(service=service)
    driver.get(URL)

    # Wait for the page to load (you might need to adjust the sleep duration)
    time.sleep(10)

    # Get the page source after it has loaded dynamically
    page_source = driver.page_source

    # Use BeautifulSoup to parse the page source
    soup = BeautifulSoup(page_source, 'html.parser')

    # Find all products on the page
    product_elements = soup.find_all('span', {'class': 'a-size-medium a-color-base a-text-normal'})

    # write a header to CSV file
    header = ['Title', 'Price', 'Date']
    with open('AmazonWebScrapperDataset1.csv', 'a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        # If the file is empty, write the header
        if f.tell() == 0:
            writer.writerow(header)

        # Iterate over product elements
        for product_element in product_elements:
            # Extract and print the title for each product
            title = product_element.get_text(strip=True)
            print(f"Title: {title}")

            # Find the parent element containing the price
            parent_element = product_element.find_parent('div', {'class': 'a-section a-spacing-small a-spacing-top-small'})

            # Extract and print the price for each product
            price_element = product_element.find_next('span', {'class': 'a-price-whole'})

            # Check if the element with id 'a-price-whole' exists
            if price_element:
                price = price_element.get_text(strip=True)
                print(f"Price: {price}")
            else:
                print("Price not found.")

            # Write the data to CSV file
            data = [title, price, today]
            writer.writerow(data)

            print('-' * 50)

    # Read and display the CSV file
    df = pd.read_csv('AmazonWebScrapperDataset1.csv')
    print(df)

    # Close the Selenium WebDriver
    driver.quit()

# %%
# This is to automate the duration for the data to refresh in this case we have set it to 172800 secs or 2 days
while (True):
    check_price()
    time.sleep(172,800)

# %%
# This is the way we can check the updated data from the URL

df = pd.read_csv('AmazonWebScrapperDataset1.csv')

print(df)
# Out:
#                                                 Title       Price  \
# 0   beatXP Vega 1.43" (3.6 cm) Super AMOLED Displa...         999
# 1   beatXP Vega 1.43" (3.6 cm) Super AMOLED Displa...         999
# 2   Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...       1,099
# 3   Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...       1,099
# 4   Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...       1,099
# 5   beatXP Vega 1.43" (3.6 cm) Super AMOLED Displa...       1,099
# 6   ('Noise Pulse 2 Max 1.85" Display, Bluetooth C...  ('1,099',)
# 7   Noise Pulse 2 Max 1.85" Display, Bluetooth Cal...       1,099
# 8   Noise Pulse 2 Max 1.85" Display, Bluetooth Cal...       1,099
# 9   Noise Pulse 2 Max 1.85" Display, Bluetooth Cal...       1,099
# 10  Noise Pulse 2 Max 1.85" Display, Bluetooth Cal...       1,099
# 11  Noise Pulse 2 Max 1.85" Display, Bluetooth Cal...       1,099
# 12  Noise Pulse 2 Max 1.85" Display, Bluetooth Cal...       1,099
# ...
